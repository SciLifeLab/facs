# %%
import os
import matplotlib
import json
from pandas import DataFrame
from facs.utils import performance

# %%
performance.fetch_couchdb_results()
# Out:
# [2014-01-15 19:34] INFO: FACS: Establishing connection with database http://facs.iriscouch.org:5984
# [2014-01-15 19:34] INFO: FACS: Fetching all documents from database facs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-cc6ba06807f8> in <module>()
# ----> 1 performance.fetch_couchdb_results()
#
# /home/romanvg/.virtualenvs/facs/local/lib/python2.7/site-packages/facs-2.0-py2.7-linux-i686.egg/facs/utils/performance.pyc in fetch_couchdb_results()
#     174             json.dump(fastq_screen_results, fh)
#     175
# --> 176         with open("deconseq.json", 'w') as fh:
#     177             json.dump(deconseq_results, fh)
#     178
#
# /home/romanvg/.virtualenvs/facs/local/lib/python2.7/site-packages/facs-2.0-py2.7-linux-i686.egg/facs/utils/performance.pyc in _fetch_results(couch, database)
#      24     log.info("Fetching all documents from database %s" % database)
#      25     docs = []
# ---> 26     db = couch[database]
#      27     [docs.append(db.get(doc)) for doc in db]
#      28     log.info("Fetched %s documents" % str(len(docs)))
#
# /home/romanvg/.virtualenvs/facs/local/lib/python2.7/site-packages/couchdb/client.pyc in __getitem__(self, name)
#     136         """
#     137         db = Database(self.resource(name), name)
# --> 138         db.resource.head() # actually make a request to the database
#     139         return db
#     140
#
# /home/romanvg/.virtualenvs/facs/local/lib/python2.7/site-packages/couchdb/http.pyc in head(self, path, headers, **params)
#     508
#     509     def head(self, path=None, headers=None, **params):
# --> 510         return self._request('HEAD', path, headers=headers, **params)
#     511
#     512     def post(self, path=None, body=None, headers=None, **params):
#
# /home/romanvg/.virtualenvs/facs/local/lib/python2.7/site-packages/couchdb/http.pyc in _request(self, method, path, body, headers, **params)
#     540         return self.session.request(method, url, body=body,
#     541                                     headers=all_headers,
# --> 542                                     credentials=self.credentials)
#     543
#     544     def _request_json(self, method, path=None, body=None, headers=None, **params):
#
# /home/romanvg/.virtualenvs/facs/local/lib/python2.7/site-packages/couchdb/http.pyc in request(self, method, url, body, headers, credentials, num_redirects)
#     278
#     279         path_query = urlunsplit(('', '') + urlsplit(url)[2:4] + ('',))
# --> 280         conn = self.connection_pool.get(url)
#     281
#     282         def _try_request_with_retries(retries):
#
# /home/romanvg/.virtualenvs/facs/local/lib/python2.7/site-packages/couchdb/http.pyc in get(self, url)
#     468                 raise ValueError('%s is not a supported scheme' % scheme)
#     469             conn = cls(host, timeout=self.timeout)
# --> 470             conn.connect()
#     471
#     472         return conn
#
# /usr/lib/python2.7/httplib.pyc in connect(self)
#     755         """Connect to the host and port specified in __init__."""
#     756         self.sock = socket.create_connection((self.host,self.port),
# --> 757                                              self.timeout, self.source_address)
#     758
#     759         if self._tunnel_host:
#
# /usr/lib/python2.7/socket.pyc in create_connection(address, timeout, source_address)
#     560             if source_address:
#     561                 sock.bind(source_address)
# --> 562             sock.connect(sa)
#     563             return sock
#     564
#
# /usr/lib/python2.7/socket.pyc in meth(name, self, *args)
#     222
#     223 def meth(name,self,*args):
# --> 224     return getattr(self._sock,name)(*args)
#     225
#     226 for _m in _socketmethods:
#
# KeyboardInterrupt:

# %%
benchmarks = json.loads(performance.facs_vs_fastq_screen())

# %%
print benchmarks.values()[0]
# Out:
# {u'contam_fqscr': 91.31, u'filter_facs': u'/pica/h1/roman/dev/facs/tests/data/bloom/dm3.bloom', u'filter_fqscr': u'dm3', u'sample_facs': u'/pica/h1/roman/dev/facs/tests/data/synthetic_fastq/simngs_dm3_1000.fastq', u'contam_facs': 0.913131, u'delta': 0.235271, u'delta_facs': 0.094, u'sample_fqscr': u'simngs_dm3_1000.fastq'}

# %%
frame = DataFrame(benchmarks.values())

# %%
# Some minor preprocessing

frame.rename(columns={'delta': 'delta_fqscr'}, inplace=True)

frame['filter_facs'] = frame.filter_facs.apply(os.path.basename)
frame['sample_facs'] = frame.sample_facs.apply(os.path.basename)

# To compare facs filters with fast_screen reference indexes we normalize names
frame['filter_facs'] = [filt[0] for filt in frame.filter_facs.map(os.path.splitext)]

# Individual column with read counts
frame['reads'] = [os.path.splitext(reads.split('_')[-1])[0] for reads in frame.sample_facs]

# Normalize fastq_screen contamination rates
frame['contam_fqscr'] = [ contam/100 for contam in frame.contam_fqscr ]

# %%
frame.sort('reads').loc[:,['reads', 'contam_fqscr', 'contam_facs']]
# Out:
#        reads  contam_fqscr  contam_facs
# 4        100        0.0000     0.000000
# 24       100        0.9556     0.944444
# 26       100        0.9556     0.000000
# 27       100        0.9556     0.000000
# 28       100        0.0000     1.000000
# 29       100        0.0000     0.000000
# 32       100        0.0000     1.000000
# 33       100        0.0000     0.000000
# 34       100        0.0000     0.000000
# 0       1000        0.9131     0.913131
# 1       1000        0.9131     0.000000
# 2       1000        0.9131     0.000000
# 18      1000        0.0000     0.000000
# 20      1000        0.0000     0.998000
# 21      1000        0.0000     0.000000
# 30      1000        0.0020     0.998000
# 31      1000        0.0020     0.002000
# 35      1000        0.0020     0.000000
# 3    1000000        0.0033     0.004011
# 8    1000000        0.0033     0.995509
# 9    1000000        0.0033     0.000000
# 10   1000000        0.9150     0.000267
# 11   1000000        0.9150     0.917649
# 13   1000000        0.9150     0.000006
# 22   1000000        0.0001     0.000000
# 23   1000000        0.0001     0.000060
# 25   1000000        0.0001     0.995203
# 5   10000000        0.0032     0.003905
# 6   10000000        0.0032     0.995448
# 7   10000000        0.0032     0.000000
# 12  10000000        0.9154     0.918067
# 14  10000000        0.9154     0.000003
# 15  10000000        0.9154     0.000239
# 16  10000000        0.0001     0.000000
# 17  10000000        0.0001     0.000067
# 19  10000000        0.0001     0.995206

# %%
frame.describe()
# Out:
#        contam_facs  contam_fqscr  delta_fqscr  delta_facs
# count    36.000000     36.000000    36.000000   36.000000
# mean      0.324478      0.308983    26.493043    1.697861
# std       0.465227      0.441732    79.908829    3.631854
# min       0.000000      0.000000     0.081602    0.000000
# 25%       0.000000      0.000075     0.084291    0.010750
# 50%       0.000063      0.002600     0.089576    0.167000
# 75%       0.924661      0.913575     0.180309    1.385250
# max       1.000000      0.955600   356.362275   19.067000

# %%
# Slicing main dataframe into individual organism dataframes

dm3 = frame['sample_fqscr'].map(lambda x: 'dm3' in x)
eschColi = frame['sample_fqscr'].map(lambda x: 'eschColi_K12' in x)
phiX = frame['sample_fqscr'].map(lambda x: 'phiX' in x)

dm3 = frame[dm3]
eschColi = frame[eschColi]
phiX = frame[phiX]

# %%
eschColi.sort('reads')
# Out:
#     contam_facs  contam_fqscr  delta_fqscr  delta_facs   filter_facs  \
# 4      0.000000        0.0000     0.082411       0.000          phiX
# 28     1.000000        0.0000     0.083486       0.004  eschColi_K12
# 29     0.000000        0.0000     0.163174       0.098           dm3
# 30     0.998000        0.0020     0.082594       0.015  eschColi_K12
# 31     0.002000        0.0020     0.199190       0.116           dm3
# 35     0.000000        0.0020     0.081602       0.013          phiX
# 3      0.004011        0.0033    31.482395       0.867           dm3
# 8      0.995509        0.0033     0.083800       0.932  eschColi_K12
# 9      0.000000        0.0033     0.082373       0.218          phiX
# 5      0.003905        0.0032   253.181050       6.455           dm3
# 6      0.995448        0.0032     0.092134       6.484  eschColi_K12
# 7      0.000000        0.0032     0.089207       1.354          phiX
#
#     filter_fqscr                         sample_facs  \
# 4           phiX       simngs_eschColi_K12_100.fastq
# 28  eschColi_K12       simngs_eschColi_K12_100.fastq
# 29           dm3       simngs_eschColi_K12_100.fastq
# 30  eschColi_K12      simngs_eschColi_K12_1000.fastq
# 31           dm3      simngs_eschColi_K12_1000.fastq
# 35          phiX      simngs_eschColi_K12_1000.fastq
# 3            dm3   simngs_eschColi_K12_1000000.fastq
# 8   eschColi_K12   simngs_eschColi_K12_1000000.fastq
# 9           phiX   simngs_eschColi_K12_1000000.fastq
# 5            dm3  simngs_eschColi_K12_10000000.fastq
# 6   eschColi_K12  simngs_eschColi_K12_10000000.fastq
# 7           phiX  simngs_eschColi_K12_10000000.fastq
#
#                           sample_fqscr     reads
# 4        simngs_eschColi_K12_100.fastq       100
# 28       simngs_eschColi_K12_100.fastq       100
# 29       simngs_eschColi_K12_100.fastq       100
# 30      simngs_eschColi_K12_1000.fastq      1000
# 31      simngs_eschColi_K12_1000.fastq      1000
# 35      simngs_eschColi_K12_1000.fastq      1000
# 3    simngs_eschColi_K12_1000000.fastq   1000000
# 8    simngs_eschColi_K12_1000000.fastq   1000000
# 9    simngs_eschColi_K12_1000000.fastq   1000000
# 5   simngs_eschColi_K12_10000000.fastq  10000000
# 6   simngs_eschColi_K12_10000000.fastq  10000000
# 7   simngs_eschColi_K12_10000000.fastq  10000000

# %%
phiX.sort('reads')
# Out:
#     contam_facs  contam_fqscr  delta_fqscr  delta_facs   filter_facs  \
# 32     1.000000        0.0000     0.081943       0.001          phiX
# 33     0.000000        0.0000     0.083104       0.004  eschColi_K12
# 34     0.000000        0.0000     0.174015       0.092           dm3
# 18     0.000000        0.0000     0.202987       0.107           dm3
# 20     0.998000        0.0000     0.085698       0.001          phiX
# 21     0.000000        0.0000     0.088315       0.004  eschColi_K12
# 22     0.000000        0.0001     0.085392       0.263  eschColi_K12
# 23     0.000060        0.0001    31.022332       1.150           dm3
# 25     0.995203        0.0001     0.085240       0.797          phiX
# 16     0.000000        0.0001     0.090104       1.762  eschColi_K12
# 17     0.000067        0.0001   231.255063       7.434           dm3
# 19     0.995206        0.0001     0.084454       5.543          phiX
#
#     filter_fqscr                 sample_facs                sample_fqscr  \
# 32          phiX       simngs_phiX_100.fastq       simngs_phiX_100.fastq
# 33  eschColi_K12       simngs_phiX_100.fastq       simngs_phiX_100.fastq
# 34           dm3       simngs_phiX_100.fastq       simngs_phiX_100.fastq
# 18           dm3      simngs_phiX_1000.fastq      simngs_phiX_1000.fastq
# 20          phiX      simngs_phiX_1000.fastq      simngs_phiX_1000.fastq
# 21  eschColi_K12      simngs_phiX_1000.fastq      simngs_phiX_1000.fastq
# 22  eschColi_K12   simngs_phiX_1000000.fastq   simngs_phiX_1000000.fastq
# 23           dm3   simngs_phiX_1000000.fastq   simngs_phiX_1000000.fastq
# 25          phiX   simngs_phiX_1000000.fastq   simngs_phiX_1000000.fastq
# 16  eschColi_K12  simngs_phiX_10000000.fastq  simngs_phiX_10000000.fastq
# 17           dm3  simngs_phiX_10000000.fastq  simngs_phiX_10000000.fastq
# 19          phiX  simngs_phiX_10000000.fastq  simngs_phiX_10000000.fastq
#
#        reads
# 32       100
# 33       100
# 34       100
# 18      1000
# 20      1000
# 21      1000
# 22   1000000
# 23   1000000
# 25   1000000
# 16  10000000
# 17  10000000
# 19  10000000

# %%
dm3.sort('reads')
# Out:
#     contam_facs  contam_fqscr  delta_fqscr  delta_facs   filter_facs  \
# 24     0.944444        0.9556     0.173166       0.091           dm3
# 26     0.000000        0.9556     0.087483       0.001          phiX
# 27     0.000000        0.9556     0.085633       0.014  eschColi_K12
# 0      0.913131        0.9131     0.235271       0.094           dm3
# 1      0.000000        0.9131     0.083754       0.004  eschColi_K12
# 2      0.000000        0.9131     0.086220       0.002          phiX
# 10     0.000267        0.9150     0.094745       0.405  eschColi_K12
# 11     0.917649        0.9150    47.221975       4.285           dm3
# 13     0.000006        0.9150     0.089945       0.331          phiX
# 12     0.918067        0.9154   356.362275      19.067           dm3
# 14     0.000003        0.9154     0.091775       1.479          phiX
# 15     0.000239        0.9154     0.095248       1.636  eschColi_K12
#
#     filter_fqscr                sample_facs               sample_fqscr  \
# 24           dm3       simngs_dm3_100.fastq       simngs_dm3_100.fastq
# 26          phiX       simngs_dm3_100.fastq       simngs_dm3_100.fastq
# 27  eschColi_K12       simngs_dm3_100.fastq       simngs_dm3_100.fastq
# 0            dm3      simngs_dm3_1000.fastq      simngs_dm3_1000.fastq
# 1   eschColi_K12      simngs_dm3_1000.fastq      simngs_dm3_1000.fastq
# 2           phiX      simngs_dm3_1000.fastq      simngs_dm3_1000.fastq
# 10  eschColi_K12   simngs_dm3_1000000.fastq   simngs_dm3_1000000.fastq
# 11           dm3   simngs_dm3_1000000.fastq   simngs_dm3_1000000.fastq
# 13          phiX   simngs_dm3_1000000.fastq   simngs_dm3_1000000.fastq
# 12           dm3  simngs_dm3_10000000.fastq  simngs_dm3_10000000.fastq
# 14          phiX  simngs_dm3_10000000.fastq  simngs_dm3_10000000.fastq
# 15  eschColi_K12  simngs_dm3_10000000.fastq  simngs_dm3_10000000.fastq
#
#        reads
# 24       100
# 26       100
# 27       100
# 0       1000
# 1       1000
# 2       1000
# 10   1000000
# 11   1000000
# 13   1000000
# 12  10000000
# 14  10000000
# 15  10000000

# %%
runtimes_dm3 = dm3.loc[:,['reads', 'delta_fqscr', 'delta_facs']]

# %%
runtimes_dm3.sort('reads')
# Out:
#        reads  delta_fqscr  delta_facs
# 24       100     0.173166       0.091
# 26       100     0.087483       0.001
# 27       100     0.085633       0.014
# 0       1000     0.235271       0.094
# 1       1000     0.083754       0.004
# 2       1000     0.086220       0.002
# 10   1000000     0.094745       0.405
# 11   1000000    47.221975       4.285
# 13   1000000     0.089945       0.331
# 12  10000000   356.362275      19.067
# 14  10000000     0.091775       1.479
# 15  10000000     0.095248       1.636

# %%
runtimes_dm3.pivot_table(values=['delta_fqscr', 'delta_facs'], rows=['reads']).plot(title='eschColi_K12 FACS vs Fastq_screen runtimes (log scale)', kind='barh', logy=True, logx=True)

# %%
runtimes_eschColi = eschColi.loc[:,['reads', 'delta_fqscr', 'delta_facs']]
runtimes_eschColi.pivot_table(values=['delta_fqscr', 'delta_facs'], rows=['reads']).plot(title='eschColi_K12 FACS vs Fastq_screen runtimes (log scale)', kind='barh', logy=True, logx=True)

runtimes_phiX = phiX.loc[:,['reads', 'delta_fqscr', 'delta_facs']]
runtimes_phiX.pivot_table(values=['delta_fqscr', 'delta_facs'], rows=['reads']).plot(title ='phiX FACS vs Fastq_screen runtimes (log scale)', kind='barh', logy=True, logx=True)

# %%
frame
# Out:
#     contam_facs  contam_fqscr  delta_fqscr  delta_facs   filter_facs  \
# 0      0.913131        0.9131     0.235271       0.094           dm3
# 1      0.000000        0.9131     0.083754       0.004  eschColi_K12
# 2      0.000000        0.9131     0.086220       0.002          phiX
# 3      0.004011        0.0033    31.482395       0.867           dm3
# 4      0.000000        0.0000     0.082411       0.000          phiX
# 5      0.003905        0.0032   253.181050       6.455           dm3
# 6      0.995448        0.0032     0.092134       6.484  eschColi_K12
# 7      0.000000        0.0032     0.089207       1.354          phiX
# 8      0.995509        0.0033     0.083800       0.932  eschColi_K12
# 9      0.000000        0.0033     0.082373       0.218          phiX
# 10     0.000267        0.9150     0.094745       0.405  eschColi_K12
# 11     0.917649        0.9150    47.221975       4.285           dm3
# 12     0.918067        0.9154   356.362275      19.067           dm3
# 13     0.000006        0.9150     0.089945       0.331          phiX
# 14     0.000003        0.9154     0.091775       1.479          phiX
# 15     0.000239        0.9154     0.095248       1.636  eschColi_K12
# 16     0.000000        0.0001     0.090104       1.762  eschColi_K12
# 17     0.000067        0.0001   231.255063       7.434           dm3
# 18     0.000000        0.0000     0.202987       0.107           dm3
# 19     0.995206        0.0001     0.084454       5.543          phiX
# 20     0.998000        0.0000     0.085698       0.001          phiX
# 21     0.000000        0.0000     0.088315       0.004  eschColi_K12
# 22     0.000000        0.0001     0.085392       0.263  eschColi_K12
# 23     0.000060        0.0001    31.022332       1.150           dm3
# 24     0.944444        0.9556     0.173166       0.091           dm3
# 25     0.995203        0.0001     0.085240       0.797          phiX
# 26     0.000000        0.9556     0.087483       0.001          phiX
# 27     0.000000        0.9556     0.085633       0.014  eschColi_K12
# 28     1.000000        0.0000     0.083486       0.004  eschColi_K12
# 29     0.000000        0.0000     0.163174       0.098           dm3
# 30     0.998000        0.0020     0.082594       0.015  eschColi_K12
# 31     0.002000        0.0020     0.199190       0.116           dm3
# 32     1.000000        0.0000     0.081943       0.001          phiX
# 33     0.000000        0.0000     0.083104       0.004  eschColi_K12
# 34     0.000000        0.0000     0.174015       0.092           dm3
# 35     0.000000        0.0020     0.081602       0.013          phiX
#
#     filter_fqscr                         sample_facs  \
# 0            dm3               simngs_dm3_1000.fastq
# 1   eschColi_K12               simngs_dm3_1000.fastq
# 2           phiX               simngs_dm3_1000.fastq
# 3            dm3   simngs_eschColi_K12_1000000.fastq
# 4           phiX       simngs_eschColi_K12_100.fastq
# 5            dm3  simngs_eschColi_K12_10000000.fastq
# 6   eschColi_K12  simngs_eschColi_K12_10000000.fastq
# 7           phiX  simngs_eschColi_K12_10000000.fastq
# 8   eschColi_K12   simngs_eschColi_K12_1000000.fastq
# 9           phiX   simngs_eschColi_K12_1000000.fastq
# 10  eschColi_K12            simngs_dm3_1000000.fastq
# 11           dm3            simngs_dm3_1000000.fastq
# 12           dm3           simngs_dm3_10000000.fastq
# 13          phiX            simngs_dm3_1000000.fastq
# 14          phiX           simngs_dm3_10000000.fastq
# 15  eschColi_K12           simngs_dm3_10000000.fastq
# 16  eschColi_K12          simngs_phiX_10000000.fastq
# 17           dm3          simngs_phiX_10000000.fastq
# 18           dm3              simngs_phiX_1000.fastq
# 19          phiX          simngs_phiX_10000000.fastq
# 20          phiX              simngs_phiX_1000.fastq
# 21  eschColi_K12              simngs_phiX_1000.fastq
# 22  eschColi_K12           simngs_phiX_1000000.fastq
# 23           dm3           simngs_phiX_1000000.fastq
# 24           dm3                simngs_dm3_100.fastq
# 25          phiX           simngs_phiX_1000000.fastq
# 26          phiX                simngs_dm3_100.fastq
# 27  eschColi_K12                simngs_dm3_100.fastq
# 28  eschColi_K12       simngs_eschColi_K12_100.fastq
# 29           dm3       simngs_eschColi_K12_100.fastq
# 30  eschColi_K12      simngs_eschColi_K12_1000.fastq
# 31           dm3      simngs_eschColi_K12_1000.fastq
# 32          phiX               simngs_phiX_100.fastq
# 33  eschColi_K12               simngs_phiX_100.fastq
# 34           dm3               simngs_phiX_100.fastq
# 35          phiX      simngs_eschColi_K12_1000.fastq
#
#                           sample_fqscr     reads
# 0                simngs_dm3_1000.fastq      1000
# 1                simngs_dm3_1000.fastq      1000
# 2                simngs_dm3_1000.fastq      1000
# 3    simngs_eschColi_K12_1000000.fastq   1000000
# 4        simngs_eschColi_K12_100.fastq       100
# 5   simngs_eschColi_K12_10000000.fastq  10000000
# 6   simngs_eschColi_K12_10000000.fastq  10000000
# 7   simngs_eschColi_K12_10000000.fastq  10000000
# 8    simngs_eschColi_K12_1000000.fastq   1000000
# 9    simngs_eschColi_K12_1000000.fastq   1000000
# 10            simngs_dm3_1000000.fastq   1000000
# 11            simngs_dm3_1000000.fastq   1000000
# 12           simngs_dm3_10000000.fastq  10000000
# 13            simngs_dm3_1000000.fastq   1000000
# 14           simngs_dm3_10000000.fastq  10000000
# 15           simngs_dm3_10000000.fastq  10000000
# 16          simngs_phiX_10000000.fastq  10000000
# 17          simngs_phiX_10000000.fastq  10000000
# 18              simngs_phiX_1000.fastq      1000
# 19          simngs_phiX_10000000.fastq  10000000
# 20              simngs_phiX_1000.fastq      1000
# 21              simngs_phiX_1000.fastq      1000
# 22           simngs_phiX_1000000.fastq   1000000
# 23           simngs_phiX_1000000.fastq   1000000
# 24                simngs_dm3_100.fastq       100
# 25           simngs_phiX_1000000.fastq   1000000
# 26                simngs_dm3_100.fastq       100
# 27                simngs_dm3_100.fastq       100
# 28       simngs_eschColi_K12_100.fastq       100
# 29       simngs_eschColi_K12_100.fastq       100
# 30      simngs_eschColi_K12_1000.fastq      1000
# 31      simngs_eschColi_K12_1000.fastq      1000
# 32               simngs_phiX_100.fastq       100
# 33               simngs_phiX_100.fastq       100
# 34               simngs_phiX_100.fastq       100
# 35      simngs_eschColi_K12_1000.fastq      1000
