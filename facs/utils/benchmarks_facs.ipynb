# %%
import os
import matplotlib
import json
from pandas import DataFrame
from facs.utils import performance

# %%
performance.fetch_couchdb_results()
# Out:
# [2014-01-12 15:29] INFO: FACS: Establishing connection with database http://facs.iriscouch.org:5984
# [2014-01-12 15:29] INFO: FACS: Fetching all documents from database facs
# [2014-01-12 15:29] INFO: FACS: Fetched 36 documents
# [2014-01-12 15:29] INFO: FACS: Fetching all documents from database fastq_screen
# [2014-01-12 15:29] INFO: FACS: Fetched 36 documents
# [2014-01-12 15:29] INFO: FACS: Fetching all documents from database deconseq
# [2014-01-12 15:29] INFO: FACS: Fetched 36 documents

# %%
benchmarks = json.loads(performance.facs_vs_fastq_screen())

# %%
print benchmarks.values()[0]
# Out:
# {u'contam_fqscr': 0.0, u'filter_facs': u'/pica/h1/roman/dev/facs/tests/data/bloom/dm3.bloom', u'filter_fqscr': u'dm3', u'sample_facs': u'/pica/h1/roman/dev/facs/tests/data/synthetic_fastq/simngs_phiX_1000000.fastq', u'contam_facs': 6e-05, u'delta': 37.399847, u'delta_facs': 0.338, u'sample_fqscr': u'simngs_phiX_1000000.fastq'}

# %%
frame = DataFrame(benchmarks.values())

# %%
# Some minor preprocessing

frame.rename(columns={'delta': 'delta_fqscr'}, inplace=True)

frame['filter_facs'] = frame.filter_facs.apply(os.path.basename)
frame['sample_facs'] = frame.sample_facs.apply(os.path.basename)

# To compare facs filters with fast_screen reference indexes we normalize names
frame['filter_facs'] = [filt[0] for filt in frame.filter_facs.map(os.path.splitext)]

# Individual column with read counts
frame['reads'] = [os.path.splitext(reads.split('_')[-1])[0] for reads in frame.sample_facs]

# %%
frame.sort('reads')[:10]
# Out:
#     contam_facs  contam_fqscr  delta_fqscr  delta_facs   filter_facs  \
# 12     0.000000             0     0.213350       0.215           dm3
# 14     1.000000             0     0.107921       0.000          phiX
# 15     0.000000             0     0.108129       0.005  eschColi_K12
# 16     0.000000            60     0.108501       0.003  eschColi_K12
# 17     0.944444            60     0.206660       0.248           dm3
# 19     0.000000            60     0.108243       0.000          phiX
# 22     1.000000             0     0.107876       0.004  eschColi_K12
# 23     0.000000             0     0.202346       0.212           dm3
# 25     0.000000             0     0.108322       0.001          phiX
# 10     0.000000             0     0.131076       0.035  eschColi_K12
#
#     filter_fqscr                    sample_facs  \
# 12           dm3          simngs_phiX_100.fastq
# 14          phiX          simngs_phiX_100.fastq
# 15  eschColi_K12          simngs_phiX_100.fastq
# 16  eschColi_K12           simngs_dm3_100.fastq
# 17           dm3           simngs_dm3_100.fastq
# 19          phiX           simngs_dm3_100.fastq
# 22  eschColi_K12  simngs_eschColi_K12_100.fastq
# 23           dm3  simngs_eschColi_K12_100.fastq
# 25          phiX  simngs_eschColi_K12_100.fastq
# 10  eschColi_K12         simngs_phiX_1000.fastq
#
#                      sample_fqscr reads
# 12          simngs_phiX_100.fastq   100
# 14          simngs_phiX_100.fastq   100
# 15          simngs_phiX_100.fastq   100
# 16           simngs_dm3_100.fastq   100
# 17           simngs_dm3_100.fastq   100
# 19           simngs_dm3_100.fastq   100
# 22  simngs_eschColi_K12_100.fastq   100
# 23  simngs_eschColi_K12_100.fastq   100
# 25  simngs_eschColi_K12_100.fastq   100
# 10         simngs_phiX_1000.fastq  1000

# %%
frame.describe()
# Out:
#        contam_facs  contam_fqscr  delta_fqscr  delta_facs
# count    36.000000     36.000000    36.000000   36.000000
# mean      0.324478     19.107500    32.259303    2.086528
# std       0.465227     27.274375    97.973846    4.210440
# min       0.000000      0.000000     0.107876    0.000000
# 25%       0.000000      0.000000     0.108616    0.005750
# 50%       0.000063      0.255000     0.114858    0.285500
# 75%       0.924661     56.050000     0.371846    2.154750
# max       1.000000     60.000000   457.836899   21.274000

# %%
# Slicing main dataframe into individual organism dataframes

dm3 = frame['sample_fqscr'].map(lambda x: 'dm3' in x)
eschColi = frame['sample_fqscr'].map(lambda x: 'eschColi_K12' in x)
phiX = frame['sample_fqscr'].map(lambda x: 'phiX' in x)

dm3 = frame[dm3]
eschColi = frame[eschColi]
phiX = frame[phiX]

# %%
eschColi.sort('reads')
# Out:
#     contam_facs  contam_fqscr  delta_fqscr  delta_facs   filter_facs  \
# 22     1.000000          0.00     0.107876       0.004  eschColi_K12
# 23     0.000000          0.00     0.202346       0.212           dm3
# 25     0.000000          0.00     0.108322       0.001          phiX
# 32     0.000000          0.20     0.145732       0.001          phiX
# 33     0.998000          0.20     0.136502       0.006  eschColi_K12
# 34     0.002000          0.20     0.657603       0.116           dm3
# 3      0.004011          0.32    39.310426       1.146           dm3
# 8      0.995509          0.32     0.115193       1.273  eschColi_K12
# 9      0.000000          0.32     0.110998       0.309          phiX
# 5      0.003905          0.31   273.490928       7.684           dm3
# 6      0.995448          0.31     0.113931       9.755  eschColi_K12
# 7      0.000000          0.31     0.108654       2.094          phiX
#
#     filter_fqscr                         sample_facs  \
# 22  eschColi_K12       simngs_eschColi_K12_100.fastq
# 23           dm3       simngs_eschColi_K12_100.fastq
# 25          phiX       simngs_eschColi_K12_100.fastq
# 32          phiX      simngs_eschColi_K12_1000.fastq
# 33  eschColi_K12      simngs_eschColi_K12_1000.fastq
# 34           dm3      simngs_eschColi_K12_1000.fastq
# 3            dm3   simngs_eschColi_K12_1000000.fastq
# 8   eschColi_K12   simngs_eschColi_K12_1000000.fastq
# 9           phiX   simngs_eschColi_K12_1000000.fastq
# 5            dm3  simngs_eschColi_K12_10000000.fastq
# 6   eschColi_K12  simngs_eschColi_K12_10000000.fastq
# 7           phiX  simngs_eschColi_K12_10000000.fastq
#
#                           sample_fqscr     reads
# 22       simngs_eschColi_K12_100.fastq       100
# 23       simngs_eschColi_K12_100.fastq       100
# 25       simngs_eschColi_K12_100.fastq       100
# 32      simngs_eschColi_K12_1000.fastq      1000
# 33      simngs_eschColi_K12_1000.fastq      1000
# 34      simngs_eschColi_K12_1000.fastq      1000
# 3    simngs_eschColi_K12_1000000.fastq   1000000
# 8    simngs_eschColi_K12_1000000.fastq   1000000
# 9    simngs_eschColi_K12_1000000.fastq   1000000
# 5   simngs_eschColi_K12_10000000.fastq  10000000
# 6   simngs_eschColi_K12_10000000.fastq  10000000
# 7   simngs_eschColi_K12_10000000.fastq  10000000

# %%
phiX.sort('reads')
# Out:
#     contam_facs  contam_fqscr  delta_fqscr  delta_facs   filter_facs  \
# 12     0.000000             0     0.213350       0.215           dm3
# 14     1.000000             0     0.107921       0.000          phiX
# 15     0.000000             0     0.108129       0.005  eschColi_K12
# 10     0.000000             0     0.131076       0.035  eschColi_K12
# 11     0.000000             0     1.882090       1.401           dm3
# 13     0.998000             0     0.108254       0.011          phiX
# 0      0.000060             0    37.399847       0.338           dm3
# 1      0.000000             0     0.111884       0.289  eschColi_K12
# 2      0.995203             0     0.109122       1.128          phiX
# 4      0.995206             0     0.108866       9.515          phiX
# 28     0.000000             0     0.114522       6.130  eschColi_K12
# 29     0.000067             0   287.358799       2.660           dm3
#
#     filter_fqscr                 sample_facs                sample_fqscr  \
# 12           dm3       simngs_phiX_100.fastq       simngs_phiX_100.fastq
# 14          phiX       simngs_phiX_100.fastq       simngs_phiX_100.fastq
# 15  eschColi_K12       simngs_phiX_100.fastq       simngs_phiX_100.fastq
# 10  eschColi_K12      simngs_phiX_1000.fastq      simngs_phiX_1000.fastq
# 11           dm3      simngs_phiX_1000.fastq      simngs_phiX_1000.fastq
# 13          phiX      simngs_phiX_1000.fastq      simngs_phiX_1000.fastq
# 0            dm3   simngs_phiX_1000000.fastq   simngs_phiX_1000000.fastq
# 1   eschColi_K12   simngs_phiX_1000000.fastq   simngs_phiX_1000000.fastq
# 2           phiX   simngs_phiX_1000000.fastq   simngs_phiX_1000000.fastq
# 4           phiX  simngs_phiX_10000000.fastq  simngs_phiX_10000000.fastq
# 28  eschColi_K12  simngs_phiX_10000000.fastq  simngs_phiX_10000000.fastq
# 29           dm3  simngs_phiX_10000000.fastq  simngs_phiX_10000000.fastq
#
#        reads
# 12       100
# 14       100
# 15       100
# 10      1000
# 11      1000
# 13      1000
# 0    1000000
# 1    1000000
# 2    1000000
# 4   10000000
# 28  10000000
# 29  10000000

# %%
dm3.sort('reads')
# Out:
#     contam_facs  contam_fqscr  delta_fqscr  delta_facs   filter_facs  \
# 16     0.000000         60.00     0.108501       0.003  eschColi_K12
# 17     0.944444         60.00     0.206660       0.248           dm3
# 19     0.000000         60.00     0.108243       0.000          phiX
# 24     0.913131         56.36     0.276594       0.219           dm3
# 26     0.000000         56.36     0.107942       0.001          phiX
# 27     0.000000         56.36     0.109112       0.003  eschColi_K12
# 18     0.917649         56.05    59.061739       3.310           dm3
# 20     0.000006         56.05     0.108433       0.282          phiX
# 21     0.000267         56.05     0.112939       0.365  eschColi_K12
# 30     0.000239         56.05     0.795539       2.745  eschColi_K12
# 31     0.918067         56.05   457.836899      21.274           dm3
# 35     0.000003         56.05     0.139943       2.337          phiX
#
#     filter_fqscr                sample_facs               sample_fqscr  \
# 16  eschColi_K12       simngs_dm3_100.fastq       simngs_dm3_100.fastq
# 17           dm3       simngs_dm3_100.fastq       simngs_dm3_100.fastq
# 19          phiX       simngs_dm3_100.fastq       simngs_dm3_100.fastq
# 24           dm3      simngs_dm3_1000.fastq      simngs_dm3_1000.fastq
# 26          phiX      simngs_dm3_1000.fastq      simngs_dm3_1000.fastq
# 27  eschColi_K12      simngs_dm3_1000.fastq      simngs_dm3_1000.fastq
# 18           dm3   simngs_dm3_1000000.fastq   simngs_dm3_1000000.fastq
# 20          phiX   simngs_dm3_1000000.fastq   simngs_dm3_1000000.fastq
# 21  eschColi_K12   simngs_dm3_1000000.fastq   simngs_dm3_1000000.fastq
# 30  eschColi_K12  simngs_dm3_10000000.fastq  simngs_dm3_10000000.fastq
# 31           dm3  simngs_dm3_10000000.fastq  simngs_dm3_10000000.fastq
# 35          phiX  simngs_dm3_10000000.fastq  simngs_dm3_10000000.fastq
#
#        reads
# 16       100
# 17       100
# 19       100
# 24      1000
# 26      1000
# 27      1000
# 18   1000000
# 20   1000000
# 21   1000000
# 30  10000000
# 31  10000000
# 35  10000000

# %%
runtimes_dm3 = dm3.loc[:,['reads', 'delta_fqscr', 'delta_facs']]

# %%
runtimes_dm3.sort('reads')
# Out:
#        reads  delta_fqscr  delta_facs
# 16       100     0.108501       0.003
# 17       100     0.206660       0.248
# 19       100     0.108243       0.000
# 24      1000     0.276594       0.219
# 26      1000     0.107942       0.001
# 27      1000     0.109112       0.003
# 18   1000000    59.061739       3.310
# 20   1000000     0.108433       0.282
# 21   1000000     0.112939       0.365
# 30  10000000     0.795539       2.745
# 31  10000000   457.836899      21.274
# 35  10000000     0.139943       2.337

# %%
runtimes_dm3.pivot_table(values=['delta_fqscr', 'delta_facs'], rows=['reads']).plot(title='eschColi_K12 FACS vs Fastq_screen runtimes (log scale)', kind='barh', logy=True, logx=True)

# %%
runtimes_eschColi = eschColi.loc[:,['reads', 'delta_fqscr', 'delta_facs']]
runtimes_eschColi.pivot_table(values=['delta_fqscr', 'delta_facs'], rows=['reads']).plot(title='eschColi_K12 FACS vs Fastq_screen runtimes (log scale)', kind='barh', logy=True, logx=True)

runtimes_phiX = phiX.loc[:,['reads', 'delta_fqscr', 'delta_facs']]
runtimes_phiX.pivot_table(values=['delta_fqscr', 'delta_facs'], rows=['reads']).plot(title ='phiX FACS vs Fastq_screen runtimes (log scale)', kind='barh', logy=True, logx=True)
